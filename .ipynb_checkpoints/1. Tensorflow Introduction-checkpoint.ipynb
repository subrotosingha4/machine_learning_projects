# %%
#Ch1_AI_for_Coders

# %% [markdown]
# # Imports

# %%
import tensorflow as tf
import numpy as np
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense

# %% [markdown]
# # Model

# %%
model = Sequential([Dense(units=1, input_shape=[1])])

# %% [markdown]
# # Model compile

# %%
model.compile(optimizer='sgd', loss='mean_squared_error')

# %% [markdown]
# # Data

# %% [markdown]
# - Data relation: Y = 2X – 1

# %%
xs = np.array([-1.0, 0.0, 1.0, 2.0, 3.0, 4.0], dtype=float)
ys = np.array([-3.0, -1.0, 1.0, 3.0, 5.0, 7.0], dtype=float)

# %% [markdown]
# # Model Training

# %%
model.fit(xs, ys, epochs=500)
# Out:
# Epoch 1/500
# 1/1 [==============================] - 0s 139ms/step - loss: 42.1258
# Epoch 2/500
# 1/1 [==============================] - 0s 1ms/step - loss: 33.5060
# Epoch 3/500
# 1/1 [==============================] - 0s 1ms/step - loss: 26.7169
# Epoch 4/500
# 1/1 [==============================] - 0s 1ms/step - loss: 21.3682
# Epoch 5/500
# 1/1 [==============================] - 0s 1ms/step - loss: 17.1530
# Epoch 6/500
# 1/1 [==============================] - 0s 1ms/step - loss: 13.8296
# Epoch 7/500
# 1/1 [==============================] - 0s 1ms/step - loss: 11.2081
# Epoch 8/500
# 1/1 [==============================] - 0s 2ms/step - loss: 9.1389
# Epoch 9/500
# 1/1 [==============================] - 0s 1ms/step - loss: 7.5043
# Epoch 10/500
# 1/1 [==============================] - 0s 2ms/step - loss: 6.2119
# Epoch 11/500
# 1/1 [==============================] - 0s 2ms/step - loss: 5.1887
# Epoch 12/500
# 1/1 [==============================] - 0s 2ms/step - loss: 4.3776
# ...

# %% [markdown]
# # Prediction

# %%
print(model.predict([10.0]))
# Out:
# WARNING:tensorflow:9 out of the last 9 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7ffca0f1c0d0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# [[18.977411]]

# %% [markdown]
# # What Network Learned

# %%
Layer_0 = Dense(units=1, input_shape=[1])
model = Sequential([Layer_0])
model.compile(optimizer='sgd', loss='mean_squared_error')

xs = np.array([-1.0, 0.0, 1.0, 2.0, 3.0, 4.0], dtype=float)
ys = np.array([-3.0, -1.0, 1.0, 3.0, 5.0, 7.0], dtype=float)

model.fit(xs, ys, epochs=500, verbose= False)

print(model.predict([10.0]))
print("Here is what the model learned: {}".format(Layer_0.get_weights()))
# Out:
# WARNING:tensorflow:10 out of the last 10 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7ffca06cef70> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# [[18.976376]]
# Here is what the model learned: [array([[1.9965758]], dtype=float32), array([-0.9893838], dtype=float32)]

# %% [markdown]
#  - The learned relationship between X and Y was Y = 1.9967953X – 0.9900647
#  - Pretty close to what we’d expect (Y = 2X – 1)
